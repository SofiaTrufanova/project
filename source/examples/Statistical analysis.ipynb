# %% [markdown]
# # Statistical analysis
#
# **Collect and process all the data from the experiments**

# %%
import numpy as np
import pandas as pd
import json

# %%
from collections import defaultdict

# %%
import os
from pathlib import Path

path = Path("../../data/").resolve()
experiments_path = path / "embeddings/MNIST/2"

# %%
file_names = ["config.json", "averaged_values.json"]

# %%
from collections.abc import MutableMapping

def flatten_dict(dictionary: dict, parent_key='', separator='/') -> dict:
    
    items = []
    for key, value in dictionary.items():
        new_key = parent_key + separator + key if parent_key else key
        if isinstance(value, MutableMapping):
            items.extend(flatten_dict(value, new_key, separator=separator).items())
        else:
            items.append((new_key, value))

    return dict(items)

# %%
def gather_data(path, file_names):
    full_data = []
    
    for node in path.iterdir():
        if not node.is_dir():
            continue

        data = {}
        for subnode in node.iterdir():
            if not subnode.is_file():
                continue

            if subnode.name in file_names:
                with open(subnode) as file:
                    data |= json.load(file)

        if data:
            full_data.append(flatten_dict(data))

    return pd.DataFrame(full_data)

# %%
data = gather_data(experiments_path, file_names)

# %%
data.columns
# Out:
# Index(['n_classes', 'batch_size_train', 'batch_size_test', 'embedding_dim',
#        'discriminator_network_inner_dim', 'distribution/henze_zirkler_(train)',
#        'distribution/henze_zirkler_(train)_std',
#        'distribution/henze_zirkler_(test)',
#        'distribution/henze_zirkler_(test)_std',
#        'distribution/shapiro_wilk_(train)',
#        'distribution/shapiro_wilk_(train)_std',
#        'distribution/shapiro_wilk_(test)',
#        'distribution/shapiro_wilk_(test)_std',
#        'distribution/dagostino_pearson_(train)',
#        'distribution/dagostino_pearson_(train)_std',
#        'distribution/dagostino_pearson_(test)',
#        'distribution/dagostino_pearson_(test)_std', 'input_p', 'output_p',
#        'capacity', 'min_capacity_for_classification', 'n_epochs',
#        'embedder_network_lr', 'discriminator_network_lr', 'training/loss',
#        'training/loss_std', 'training/mutual_information',
#        'training/mutual_information_std',
#        'training/kullback_leibler_upper_bound',
#        'training/kullback_leibler_upper_bound_std',
#        'clustering/silhouette_score', 'clustering/silhouette_score_std',
#        'clustering/davies_bouldin_score',
#        'clustering/davies_bouldin_score_std',
#        'clustering/calinski_harabasz_score',
#        'clustering/calinski_harabasz_score_std',
#        'classification_logistic_regression/roc_auc',
#        'classification_logistic_regression/roc_auc_std',
#        'classification_logistic_regression/accuracy',
#        'classification_logistic_regression/accuracy_std',
#        'classification_logistic_regression/f1',
#        'classification_logistic_regression/f1_std',
#        'classification_gaussian_naive_bayes/roc_auc',
#        'classification_gaussian_naive_bayes/roc_auc_std',
#        'classification_gaussian_naive_bayes/accuracy',
#        'classification_gaussian_naive_bayes/accuracy_std',
#        'classification_gaussian_naive_bayes/f1',
#        'classification_gaussian_naive_bayes/f1_std',
#        'classification_knn/roc_auc', 'classification_knn/roc_auc_std',
#        'classification_knn/accuracy', 'classification_knn/accuracy_std',
#        'classification_knn/f1', 'classification_knn/f1_std',
#        'classification_mlp/roc_auc', 'classification_mlp/roc_auc_std',
#        'classification_mlp/accuracy', 'classification_mlp/accuracy_std',
#        'classification_mlp/f1', 'classification_mlp/f1_std'],
#       dtype='object')

# %%
data.groupby(["capacity"])[["output_p", "training/mutual_information", "training/kullback_leibler_upper_bound", "clustering/silhouette_score", "distribution/henze_zirkler_(test)", "classification_mlp/accuracy"]].mean()
# Out:
#            output_p  training/mutual_information  \
# capacity
# 0.575646   0.749894                     0.561946
# 1.151293   0.562341                     1.112670
# 2.302585   0.316228                     2.140525
# 3.453878   0.177828                     3.018134
# 4.605170   0.100000                     3.644869
# 6.907755   0.031623                     4.185015
# 9.210340   0.010000                     4.287558
# 11.512925  0.003162                     4.309556
# 13.815511  0.001000                     4.310678
#
#            training/kullback_leibler_upper_bound  clustering/silhouette_score  \
# capacity
# 0.575646                                0.013701                     0.241132
# 1.151293                                0.038623                     0.192042
# 2.302585                                0.162060                     0.109758
# 3.453878                                0.435743                     0.103048
# 4.605170                                0.960301                     0.133835
# 6.907755                                2.722740                     0.155600
# 9.210340                                4.922783                     0.142566
# 11.512925                               7.203369                     0.146359
# 13.815511                               9.504833                     0.152633
#
#            distribution/henze_zirkler_(test)  classification_mlp/accuracy
# capacity
# 0.575646                            0.006910                     0.780173
# 1.151293                            0.295867                     0.795673
# 2.302585                            0.451149                     0.783053
# 3.453878                            0.436809                     0.785967
# 4.605170                            0.396830                     0.830053
# 6.907755                            0.266976                     0.870000
# 9.210340                            0.052591                     0.873167
# 11.512925                           0.009867                     0.867993
# 13.815511                           0.005998                     0.881820
